# %%
import numpy as np
import pandas as pd
import os
from  yaml import safe_load
import tqdm
import pickle

# %%
filenames = []
for file in os.listdir('t20s'):
    filenames.append(os.path.join('t20s', file))

# %%
filenames[0:5]
# Out:
# ['t20s\\1001349.yaml',
#  't20s\\1001351.yaml',
#  't20s\\1001353.yaml',
#  't20s\\1004729.yaml',
#  't20s\\1007655.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm.tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df], ignore_index=True)
        counter += 1
        
final_df
# Out:
# 100%|██████████| 5341/5341 [1:07:46<00:00,  1.31it/s]
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ...                                                 ...                ...
# 5336  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 5337  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 5338  [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 5339  [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 5340  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
# ...

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ...                                                 ...                ...
# 5336  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 5337  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 5338  [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 5339  [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 5340  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
# ...

# %%
final_df.shape
# Out:
# (5341, 8174)

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      3366
# female    1975
# Name: count, dtype: int64

# %%
final_df['info.gender'].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
final_df = final_df[final_df['info.gender'] == 'male']

# %%
final_df.drop('info.gender', axis = 1, inplace = True)

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.balls_per_over', 'info.dates', 'info.match_type',
#        'info.outcome.by.wickets', 'info.outcome.winner', 'info.overs',
#        ...
#        'info.registry.people.Muhammad Kaleem',
#        'info.registry.people.Usman Mushtaq',
#        'info.registry.people.Mohammad Shahid',
#        'info.registry.people.Muktar Ali',
#        'info.registry.people.Mohammad Usman',
#        'info.registry.people.VS Wategaonkar',
#        'info.registry.people.Farhan Ahmed',
#        'info.registry.people.Khurram Manzoor', 'info.registry.people.P Negi',
#        'info.registry.people.Hafiz Qaleem'],
#       dtype='str', length=8173)

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    3358
# 50       8
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]

# %%
final_df.drop(columns = [col for col in final_df.columns if "info.registry" in col], inplace = True)

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ...                                                 ...                ...
# 5336  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 5337  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 5338  [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 5339  [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 5340  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
# ...

# %%
for i in final_df.columns:
    print(i)
# Out:
# innings
# meta.data_version
# meta.created
# meta.revision
# info.balls_per_over
# info.dates
# info.match_type
# info.outcome.by.wickets
# info.outcome.winner
# info.overs
# info.player_of_match
# info.players.Australia
# info.players.Sri Lanka
# info.teams
# info.toss.decision
# info.toss.winner
# info.umpires
# info.venue
# match_id
# info.city
# info.outcome.by.runs
# info.players.Hong Kong
# info.players.Ireland
# info.players.India
# info.players.Zimbabwe
# info.players.Bangladesh
# info.players.New Zealand
# info.players.South Africa
# info.players.England
# info.match_type_number
# info.players.West Indies
# info.neutral_venue
# info.outcome.result
# info.outcome.method
# info.players.Pakistan
# info.players.Scotland
# info.players.Netherlands
# info.players.Oman
# info.players.United Arab Emirates
# info.players.Papua New Guinea
# info.players.ICC World XI
# info.players.Nepal
# info.outcome.eliminator
# info.players.Thailand
# info.players.Uganda
# info.players.Malaysia
# ...

# %%
final_df.drop(columns = [col for col in final_df.columns if "info.players" in col], inplace= True)

# %%
back_up = final_df.copy

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.balls_per_over', 'info.dates', 'info.match_type',
#        'info.outcome.by.wickets', 'info.outcome.winner', 'info.overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'match_id',
#        'info.city', 'info.outcome.by.runs', 'info.match_type_number',
#        'info.neutral_venue', 'info.outcome.result', 'info.outcome.method',
#        'info.outcome.eliminator', 'info.toss.uncontested',
#        'info.supersubs.New Zealand', 'info.supersubs.South Africa',
#        'info.bowl_out', 'info.outcome.bowl_out'],
#       dtype='str')

# %%
final_df = final_df[['innings', 'info.dates', 'info.teams', 'info.outcome.winner', 'info.venue', 'match_id', 'info.city', 'info.bowl_out']]

# %%
final_df
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 5336  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 5337  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 5338  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 5339  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 5340  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#                                info.teams info.outcome.winner  \
# 0                  [Australia, Sri Lanka]           Sri Lanka
# ...

# %%
final_df.iloc[0]['innings'][0]['1st innings']
# Out:
# {'team': 'Australia',
#  'deliveries': [{0.1: {'batsman': 'AJ Finch',
#     'bowler': 'SL Malinga',
#     'non_striker': 'M Klinger',
#     'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#   {0.2: {'batsman': 'AJ Finch',
#     'bowler': 'SL Malinga',
#     'non_striker': 'M Klinger',
#     'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#   {0.3: {'batsman': 'AJ Finch',
#     'bowler': 'SL Malinga',
#     'non_striker': 'M Klinger',
#     'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#   {0.4: {'batsman': 'M Klinger',
#     'bowler': 'SL Malinga',
#     'non_striker': 'AJ Finch',
#     'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#   {0.5: {'batsman': 'M Klinger',
#     'bowler': 'SL Malinga',
#     'non_striker': 'AJ Finch',
#     'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#   {0.6: {'batsman': 'M Klinger',
#     'bowler': 'SL Malinga',
#     'non_striker': 'AJ Finch',
#     'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in final_df.iterrows():
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df, loop_df])

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121      3359  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122      3359  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123      3359  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124      3359  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125      3359  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121      3359  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122      3359  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123      3359  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124      3359  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125      3359  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# <StringArray>
# [              'Australia',               'Hong Kong',
#                 'Zimbabwe',                   'India',
#               'Bangladesh',             'New Zealand',
#             'South Africa',                 'England',
#              'West Indies',                'Pakistan',
#  ...
#                   'Mexico',                'Cambodia',
#               'Costa Rica',                'Mongolia',
#                   'Brazil',             'Ivory Coast',
#                 'Suriname', 'Turks and Caicos Island',
#              'Timor-Leste',                  'Zambia']
# Length: 106, dtype: str

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121      3359    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122      3359    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123      3359    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124      3359    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125      3359    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121      3359    Sri Lanka    Australia  19.3     1                0  Colombo
# 122      3359    Sri Lanka    Australia  19.4     0                0  Colombo
# 123      3359    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124      3359    Sri Lanka    Australia  19.6     2                0  Colombo
# 125      3359    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
pickle.dump(output,open('dataset.pkl','wb'))
